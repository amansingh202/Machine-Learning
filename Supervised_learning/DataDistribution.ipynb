# %%
#larger dataset
import numpy as np

x = np.random.uniform(0.0, 5, 250)
#for 250 different values

print(x)
# Out:
# [4.43351799 2.37532772 4.16152609 2.16382996 0.97690288 4.69552339
#  4.02551941 4.5312863  0.62835855 4.07961294 1.29152524 4.51703634
#  2.42324707 1.67518887 1.06879734 4.20587207 3.28928255 1.94487196
#  2.44260275 1.78443327 2.58244616 0.90153164 2.54360875 3.26118756
#  0.57925303 1.75554897 2.19473918 4.10147722 3.5604274  0.5487006
#  1.44576326 0.54287121 1.45520635 1.56775581 2.55457609 1.75285049
#  0.84050639 0.76418042 3.49468018 4.60122027 2.99000761 1.05721962
#  1.5522483  4.55975223 4.91580012 0.29286297 3.15790229 0.46497956
#  3.76693688 0.96482309 0.55742461 2.45305205 0.53760675 2.914547
#  4.91823491 1.43897202 4.12261874 1.68944707 0.3939897  2.39898074
#  0.21004544 4.60412759 0.55142632 2.11336223 2.8393352  3.3571456
#  4.01510766 3.84162289 3.86686306 1.19012306 2.28627556 4.7587881
#  3.28223775 4.61567979 0.32866368 4.84347483 1.11775866 0.27616125
#  1.8456948  4.44150155 4.00044547 1.10667972 4.04534535 4.96291192
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(x, 6)
plt.show()

# %%
#for an extremely large dataset
y = np.random.uniform(0,5,1000000)

plt.hist(y, 100)
plt.show()
