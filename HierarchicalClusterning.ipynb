# %% [markdown]
# # Hierarchical Clustering (unsupervised Learning)
# Bottom up approach<br>
# shortest distance between them to create large cluster

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x,y)
plt.show()

# %%
data = list(zip(x, y))

linkage_data = linkage(data, method = 'ward', metric = 'euclidean')
dendogram(linkage_data)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 data = list(zip(x, y))
# ----> 3 linkage_data = linkage(data, method = 'ward', metric = 'euclidean')
#       4 dendogram(linkage_data)
#       6 plt.show()
#
# NameError: name 'linkage' is not defined
