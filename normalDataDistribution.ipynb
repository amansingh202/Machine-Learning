# %% [markdown]
# # Normal Data Distribution

# %% [markdown]
# Normal data Distribution means concentration of data around a value

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(5, 1, 1000000)

plt.hist(x, 100)
plt.show()
